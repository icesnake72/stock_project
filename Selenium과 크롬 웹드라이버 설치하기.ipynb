# %% [markdown]
# # Selenium 설치하기
#
# ## Selenium은?
#
# Selenium은 웹브라우져 자동화 라이브러리 입니다
#
#
# ## Selenium의 설치
#
# pip(또는 pip3)을 이용하여 Selenium 라이브러리를 설치할 수 있다

# %%
pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 46.9 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#   Using cached trio_websocket-0.10.2-py3-none-any.whl (17 kB)
# ...
#   Using cached trio-0.22.0-py3-none-any.whl (384 kB)
# ...
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# ...
#   Using cached async_generator-1.10-py3-none-any.whl (18 kB)
# ...
#   Using cached exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# ...
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---

# %% [markdown]
# ## Chrome Webdriver 설치
#
# #### 나의 크롬 브라우저를 열고, 메뉴에서 '설정 >> Chrome 정보' 를 클릭하여 크롬 브라우져의 버전을 확인한다

# %% [markdown]
# ![Screen%20Shot%202023-05-27%20at%2016.52.03%20PM-2.png](attachment:Screen%20Shot%202023-05-27%20at%2016.52.03%20PM-2.png)

# %% [markdown]
# #### Chrome Driver 다운로드 페이지에서 적당한 버전의 크롬 웹드라이버를 다운로드 받는다.
#
# [크롬 웹드라이버 다운로드 페이지](https://chromedriver.chromium.org/downloads)
# https://chromedriver.chromium.org/downloads

# %% [markdown]
# ![Screen%20Shot%202023-05-27%20at%2016.58.25%20PM.png](attachment:Screen%20Shot%202023-05-27%20at%2016.58.25%20PM.png)

# %% [markdown]
# #### 버전에 맞는 크롬 웹드라이버를 설치후 적당한 곳에 압축을 풀어준다
# #### 가능하면 프로젝트 파일이 위치한 곳에 같이 있으면 좋다 (필수 사항은 아니다)

# %%
# webdriver 라이브러리를 import 한다

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
url = 'https://naver.com/'
driver = webdriver.Chrome()
driver.get(url)

# %% [markdown]
# #### 위와 ㄱ
